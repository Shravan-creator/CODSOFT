# %%
import pandas as pd

# %%
sales = pd.read_csv('/content/advertising.csv')

# %%
sales.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
sales.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
sales.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
y = sales['Sales']
x = sales[['TV','Radio','Newspaper']]

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train, y_test = train_test_split(x,y,train_size = 0.7, random_state = 2529)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((140, 3), (60, 3), (140,), (60,))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 4.7919271630779114

# %%
model.coef_
# Out:
# array([0.05523157, 0.09688879, 0.00014456])

# %%
y_predict = model.predict(x_test)

# %%
y_predict
# Out:
# array([21.82652536, 17.38886595,  6.14372237,  7.0004946 , 12.70404301,
#        22.7175242 , 12.33854403, 10.71055887, 13.69430175, 14.21071454,
#        14.84888303,  9.01986696, 18.1300194 , 22.19642066, 21.2462174 ,
#        20.30077295, 19.25898155, 13.33333179, 16.91252953, 20.79002598,
#        12.01461371, 19.36195959, 10.00917697, 16.18380389, 11.06398109,
#        22.0939562 ,  5.47052968, 11.26782957, 15.83263638, 18.87859638,
#        24.85312411, 15.46990598, 11.14909184, 20.5699337 , 10.79706518,
#        10.92240503,  6.14311052, 13.86937216, 18.40143194,  8.91550379,
#        14.17713144, 16.08217044, 17.38718569, 19.72653323, 10.21430249,
#         9.76348701, 23.36899516, 21.16253838, 21.24948348, 22.06553984,
#        17.49924935, 24.69421384,  6.46880985, 24.1789535 , 17.406744  ,
#        20.2134184 , 11.67285057, 18.36592006, 22.97819963, 24.53449949])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
mean_squared_error(y_test,y_predict)
# Out:
# 2.121193501827925

# %%
r2_score(y_test,y_predict)
# Out:
# 0.931267075844677
